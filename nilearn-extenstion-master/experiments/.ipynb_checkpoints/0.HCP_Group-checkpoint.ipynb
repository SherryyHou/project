# %%
# %matplotlib inline

# %% [markdown]
# Group analysis of resting-state fMRI with ICA: CanICA
# =====================================================
#
# An example applying CanICA to resting-state data. This example applies it
# to 30 subjects of the ADHD200 datasets. Then it plots a map with all the
# components together and an axial cut for each of the components separately.
#
# CanICA is an ICA method for group-level analysis of fMRI data. Compared
# to other strategies, it brings a well-controlled group model, as well as a
# thresholding algorithm controlling for specificity and sensitivity with
# an explicit model of the signal. The reference papers are:
#
#     * G. Varoquaux et al. "A group model for stable multi-subject ICA on
#       fMRI datasets", NeuroImage Vol 51 (2010), p. 288-299
#
#     * G. Varoquaux et al. "ICA-based sparse features recovery from fMRI
#       datasets", IEEE ISBI 2010, p. 1177
#
# Pre-prints for both papers are available on hal
# (http://hal.archives-ouvertes.fr)
#
# <div class="alert alert-info"><h4>Note</h4><p>The use of the attribute `components_img_` from decomposition
#     estimators is implemented from version 0.4.1.
#     For older versions, unmask the deprecated attribute `components_`
#     to get the components image using attribute `masker_` embedded in
#     estimator.
#     See the `section Inverse transform: unmasking data <unmasking_step>`.</p></div>

# %% [markdown]
# First we load the ADHD200 data
# -------------------------------

# %%
import os

func_filenames=[]
for x in os.listdir('/home/share/TmpData/Qinglin/HCP'):
    #print(x)
    file='/home/share/TmpData/Qinglin/HCP/'+str(x)+'/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz'
    #file="/srv1/HCP_4mm/"+str(x)+"/MNINonLinear/Results/tfMRI_EMOTION_LR/tfMRI_EMOTION_LR_hp200_s4.feat/filtered_func_data.nii.gz"   
    if os.path.isfile(file):
        func_filenames.append(file)
print func_filenames
# Out:
# ['/home/share/TmpData/Qinglin/HCP/102816/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/103818/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/101410/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/108323/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/108121/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/108828/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/101107/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/103111/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/106319/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/109325/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/101309/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/100408/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/105115/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/109123/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/105014/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/104820/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/102311/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/106521/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/107321/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/105216/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/100307/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/101006/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/106016/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/108525/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/102008/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/101915/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/107422/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/103414/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/103515/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz', '/home/share/TmpData/Qinglin/HCP/110411/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz']

# %% [markdown]
# Here we apply CanICA on the data
# ---------------------------------

# %%
from nilearn.decomposition import CanICA

canica = CanICA(n_components=40, smoothing_fwhm=6.,
                memory="nilearn_cache", memory_level=2,
                threshold=3., verbose=10, random_state=0)
data=canica.prepare_data(func_filenames)
print(data.shape)

import numpy as np
np.save('/home/share/TmpData/Qinglin/HCP_Group/MOTOR_30.npy', data)

canica._raw_fit(data)
# Retrieve the independent components in brain space. Directly
# accesible through attribute `components_img_`. Note that this
# attribute is implemented from version 0.4.1. For older versions,
# see note section above for details.
components_img = canica.components_img_
# components_img is a Nifti Image object, and can be saved to a file with
# the following line:
components_img.to_filename('canica_resting_state.nii.gz')
# Out:
# [MultiNiftiMasker.fit] Loading data from [/home/share/TmpData/Qinglin/HCP/102816/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz, /home/share/TmpData/Qinglin/HCP/103818/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz, /ho
# [MultiNiftiMasker.fit] Computing mask
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    5.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   12.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   19.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  2.8min finished
# [MultiNiftiMasker.transform] Resampling mask
# [CanICA] Loading data
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/102816/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/103818/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/101410/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/108323/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/108121/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/108828/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/101107/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/103111/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/106319/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/109325/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/101309/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/100408/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/105115/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/109123/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/105014/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/104820/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/102311/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/106521/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/107321/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/105216/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/100307/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/101006/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/106016/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/108525/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/102008/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/101915/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/107422/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/103414/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/103515/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('/home/share/TmpData/Qinglin/HCP/110411/MNINonLinear/Results/tfMRI_MOTOR_LR/tfMRI_MOTOR_LR.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# (1200, 214622)
# ________________________________________________________________________________
# [Memory] Calling sklearn.utils.extmath.randomized_svd...
# randomized_svd(array([[-0.002677, ..., -0.001588],
#        ...,
#        [-0.00234 , ...,  0.00128 ]], dtype=float32), n_iter=3, random_state=0, transpose=True, n_components=40)
# __________________________________________________randomized_svd - 10.0s, 0.2min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition.fastica_.fastica...
# fastica(array([[0.001666, ..., 0.001011],
#        ...,
#        [0.001754, ..., 0.002818]]), fun='cube', random_state=209652396, whiten=True)
# _________________________________________________________fastica - 23.5s, 0.4min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   23.6s remaining:    0.0s
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition.fastica_.fastica...
# fastica(array([[0.001666, ..., 0.001011],
#        ...,
#        [0.001754, ..., 0.002818]]), fun='cube', random_state=398764591, whiten=True)
# _________________________________________________________fastica - 33.7s, 0.6min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   57.5s remaining:    0.0s
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition.fastica_.fastica...
# fastica(array([[0.001666, ..., 0.001011],
#        ...,
#        [0.001754, ..., 0.002818]]), fun='cube', random_state=924231285, whiten=True)
# _________________________________________________________fastica - 23.9s, 0.4min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  1.4min remaining:    0.0s
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition.fastica_.fastica...
# fastica(array([[0.001666, ..., 0.001011],
#        ...,
#        [0.001754, ..., 0.002818]]), fun='cube', random_state=1478610112, whiten=True)
# _________________________________________________________fastica - 22.6s, 0.4min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.7min remaining:    0.0s
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition.fastica_.fastica...
# fastica(array([[0.001666, ..., 0.001011],
#        ...,
#        [0.001754, ..., 0.002818]]), fun='cube', random_state=441365315, whiten=True)
# _________________________________________________________fastica - 52.6s, 0.9min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  2.6min remaining:    0.0s
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition.fastica_.fastica...
# fastica(array([[0.001666, ..., 0.001011],
#        ...,
#        [0.001754, ..., 0.002818]]), fun='cube', random_state=1537364731, whiten=True)
# _________________________________________________________fastica - 27.1s, 0.5min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  3.1min remaining:    0.0s
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition.fastica_.fastica...
# fastica(array([[0.001666, ..., 0.001011],
#        ...,
#        [0.001754, ..., 0.002818]]), fun='cube', random_state=192771779, whiten=True)
# _________________________________________________________fastica - 16.3s, 0.3min
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  3.3min remaining:    0.0s
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition.fastica_.fastica...
# fastica(array([[0.001666, ..., 0.001011],
#        ...,
#        [0.001754, ..., 0.002818]]), fun='cube', random_state=1491434855, whiten=True)
# _________________________________________________________fastica - 30.9s, 0.5min
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  3.9min remaining:    0.0s
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition.fastica_.fastica...
# fastica(array([[0.001666, ..., 0.001011],
#        ...,
#        [0.001754, ..., 0.002818]]), fun='cube', random_state=1819583497, whiten=True)
# _________________________________________________________fastica - 17.9s, 0.3min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  4.2min remaining:    0.0s
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition.fastica_.fastica...
# fastica(array([[0.001666, ..., 0.001011],
#        ...,
#        [0.001754, ..., 0.002818]]), fun='cube', random_state=530702035, whiten=True)
# _________________________________________________________fastica - 24.9s, 0.4min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  4.6min finished

# %% [markdown]
# To visualize we plot the outline of all components on one figure
# -----------------------------------------------------------------

# %%
from nilearn.plotting import plot_prob_atlas

# Plot all ICA components together
plot_prob_atlas(components_img, title='All ICA components')
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/contour.py:1230: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %% [markdown]
# Finally, we plot the map for each ICA component separately
# -----------------------------------------------------------

# %%
from nilearn.image import iter_img
from nilearn.plotting import plot_stat_map, show

for i, cur_img in enumerate(iter_img(components_img)):
    plot_stat_map(cur_img, display_mode="z", title="IC %d" % i,
                  cut_coords=1, colorbar=False)

show()
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.py:522: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
